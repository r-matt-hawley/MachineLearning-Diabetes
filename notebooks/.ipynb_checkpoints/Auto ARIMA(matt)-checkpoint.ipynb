# %%
import pandas as pd
import numpy

# %%
data = pd.read_csv("dexcomData.csv")

# %%
data.head()
# Out:
#    Blood Glucose (mg/dL)  Rate (mg/dL/min)            Timestamp
# 0                  206.0               0.4  2018-10-27 21:27:07
# 1                  205.0               0.3  2018-10-27 21:22:07
# 2                  203.0               0.1  2018-10-27 21:17:07
# 3                  202.0               0.1  2018-10-27 21:12:07
# 4                  202.0               0.1  2018-10-27 21:07:07

# %%
data["Timestamp"] = pd.to_datetime(data["Timestamp"])

# %%
print(type(data["Timestamp"][0]))
data.head()

# %%
data = data.sort_values(["Timestamp"])
data
# Out:
#        Blood Glucose (mg/dL)  Rate (mg/dL/min)           Timestamp
# 73525                   72.0               0.8 2017-09-11 22:22:07
# 73524                   78.0               1.2 2017-09-11 22:26:59
# 73523                   69.0               0.6 2017-09-11 22:31:59
# 73522                   70.0              12.7 2017-09-11 22:36:58
# 73521                   61.0              12.7 2017-09-11 22:41:59
# 73520                   39.0              -2.1 2017-09-11 22:46:59
# 73519                   39.0              -2.2 2017-09-11 22:51:59
# 73518                   39.0              -2.1 2017-09-11 22:56:58
# 73517                   39.0              -0.8 2017-09-11 23:01:59
# 73516                   39.0              -1.0 2017-09-11 23:06:59
# 73515                   39.0              -0.8 2017-09-11 23:11:59
# 73514                   39.0              12.7 2017-09-11 23:16:58
# 73513                   39.0              12.7 2017-09-11 23:21:59
# 73512                   48.0              12.7 2017-09-11 23:26:59
# 73511                   77.0              12.7 2017-09-11 23:41:59
# 73510                   80.0              12.7 2017-09-11 23:46:58
# 73509                   74.0              12.7 2017-09-11 23:51:58
# 73508                   73.0              12.7 2017-09-11 23:56:59
# 73507                   62.0              12.7 2017-09-12 00:01:59
# 73506                   58.0              12.7 2017-09-12 00:06:58
# 73505                   55.0              -1.0 2017-09-12 00:11:58
# 73504                   54.0              -0.7 2017-09-12 00:16:57
# 73503                   51.0              -0.5 2017-09-12 00:21:58
# 73502                   47.0              -0.5 2017-09-12 00:26:58
# 73501                   43.0              -0.7 2017-09-12 00:31:57
# 73500                   39.0              -0.8 2017-09-12 00:36:58
# 73499                   39.0              -0.6 2017-09-12 00:41:58
# 73498                   40.0              -0.2 2017-09-12 00:46:57
# 73497                   42.0               0.1 2017-09-12 00:51:58
# 73496                   70.0               0.5 2017-09-12 00:57:04
# ...                      ...               ...                 ...
# 29                     165.0              -0.5 2018-10-27 19:02:07
# 28                     161.0              -0.9 2018-10-27 19:07:07
# 27                     156.0              -1.0 2018-10-27 19:12:07
# 26                     159.0              -0.5 2018-10-27 19:17:07
# 25                     163.0               0.1 2018-10-27 19:22:08
# 24                     160.0               0.1 2018-10-27 19:27:07
# 23                     160.0               0.1 2018-10-27 19:32:07
# 22                     160.0              -0.1 2018-10-27 19:37:06
# 21                     163.0               0.2 2018-10-27 19:42:07
# 20                     164.0               0.4 2018-10-27 19:47:07
# 19                     167.0               0.6 2018-10-27 19:52:07
# 18                     169.0               0.6 2018-10-27 19:57:07
# 17                     176.0               0.9 2018-10-27 20:02:07
# 16                     179.0               1.0 2018-10-27 20:07:07
# 15                     186.0               1.3 2018-10-27 20:12:07
# 14                     180.0               0.4 2018-10-27 20:17:07
# 13                     189.0               0.8 2018-10-27 20:22:07
# 12                     188.0               0.5 2018-10-27 20:27:07
# 11                     190.0               0.6 2018-10-27 20:32:07
# 10                     194.0               0.7 2018-10-27 20:37:07
# 9                      196.0               0.6 2018-10-27 20:42:07
# 8                      199.0               0.7 2018-10-27 20:47:07
# 7                      200.0               0.5 2018-10-27 20:52:07
# 6                      201.0               0.4 2018-10-27 20:57:07
# 5                      202.0               0.3 2018-10-27 21:02:07
# 4                      202.0               0.1 2018-10-27 21:07:07
# 3                      202.0               0.1 2018-10-27 21:12:07
# 2                      203.0               0.1 2018-10-27 21:17:07
# 1                      205.0               0.3 2018-10-27 21:22:07
# 0                      206.0               0.4 2018-10-27 21:27:07
#
# [73526 rows x 3 columns]

# %%
# "Login" to plotly (Only need to do this once...ever? Like, until you get your own login)
import plotly
plotly.tools.set_credentials_file(username='t1dhighlow', api_key='qoMfu8em7ZCrDL9rhGri')

# %%
# Define time period. Time format: yyyy-mm-dd
mask = (data['Timestamp'] > '2017-09-12') & (data['Timestamp'] <= '2017-09-19')
daydf = data.loc[mask]

# Use only the BG and Time columns to graph
plot_data = pd.DataFrame(data={"Blood Glucose":daydf["Blood Glucose (mg/dL)"], "Timestamp":daydf["Timestamp"]})
plot_data = plot_data.set_index("Timestamp")
plot_data.head()
# Out:
#                      Blood Glucose
# Timestamp
# 2017-09-12 00:01:59           62.0
# 2017-09-12 00:06:58           58.0
# 2017-09-12 00:11:58           55.0
# 2017-09-12 00:16:57           54.0
# 2017-09-12 00:21:58           51.0

# %%
# Use this to see all data. Spoiler alert: it takes a while to plot: about 30 seconds on my machine.
plot_data = pd.DataFrame(data={"Blood Glucose":data["Blood Glucose (mg/dL)"], "Timestamp":data["Timestamp"]})
plot_data = plot_data.set_index("Timestamp")
plot_data.head()

# %%
# Plot data
import plotly.plotly as ply
import cufflinks as cf
plot_data.iplot(title="Glucose Data Nov 2017")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~t1dhighlow/4.embed" height="525px" width="100%"></iframe>

# %%
print(type(plot_data.index))
print(plot_data.index.inferred_freq)

# %%
print(plot_data.index[0])

# %%
# Change Timestamps so that they are in exact 5 minute increments
agg_min = plot_data.groupby(pd.Grouper(freq='5Min')).aggregate(numpy.sum)
agg_5m.head()

# %%
# Change Timestamps so that they are in exact 5 minute increments
agg_5m = plot_data.groupby(pd.Grouper(freq='5min')).aggregate(numpy.sum)
agg_5m.head()
# Out:
#                      Blood Glucose
# Timestamp
# 2017-09-12 00:00:00           62.0
# 2017-09-12 00:05:00           58.0
# 2017-09-12 00:10:00           55.0
# 2017-09-12 00:15:00           54.0
# 2017-09-12 00:20:00           51.0

# %%
agg_5m.index[0]

# %%
# Change Timestamps so that they are in exact 60 minute increments
agg_hour = plot_data.groupby(pd.Grouper(freq="60Min")).aggregate(numpy.average)
agg_hour.head()
# Out:
#                      Blood Glucose
# Timestamp
# 2017-09-12 00:00:00      50.000000
# 2017-09-12 01:00:00      95.583333
# 2017-09-12 02:00:00     101.833333
# 2017-09-12 03:00:00      98.166667
# 2017-09-12 04:00:00      93.083333

# %%
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(agg_hour, model='additive')
fig = result.plot()
plt.show(fig)

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8

decomposition = sm.tsa.seasonal_decompose(agg_hour, model='additive')
fig = decomposition.plot()
plt.show()

# %%
from pyramid.arima import auto_arima
stepwise_model = auto_arima(agg_5m, start_p=1, start_q=1,
                           max_p=3, max_q=3, m=1095,
                           start_P=0, seasonal=True,
                           d=1, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
print(stepwise_model.aic())

# %%
train = agg_5m.loc['2017-09-12':'2017-09-18']
test = agg_5m.loc['2017-09-18':]

# %%
stepwise_model.fit(train)
# Out:
# ARIMA(callback=None, disp=0, maxiter=50, method=None, order=(1, 1, 1),
#    out_of_sample_size=0, scoring='mse', scoring_args={},
#    seasonal_order=(0, 1, 1, 12), solver='lbfgs', start_params=None,
#    suppress_warnings=True, transparams=True, trend='c')

# %%
future_forecast = stepwise_model.predict(n_periods=len(test))
future_forecast
# Out:
# array([140.59744284, 139.17277695, 138.81744683, 138.70660912,
#        138.58716859, 138.48562017, 138.23862011, 139.9261134 ,
#        140.20082256, 139.55625061, 139.44991135, 139.33664895,
#        138.85664   , 137.37593888, 136.97987829, 136.83924725,
#        136.69782933, 136.57988897, 136.32048846, 137.9984337 ,
#        138.26563322, 137.61500832, 137.50365708, 137.38612661,
#        136.90238121, 135.41832355, 135.0191779 , 134.87565582,
#        134.7314855 , 134.61089182, 134.34890879, 136.02432212,
#        136.28902588, 135.63593106, 135.52212837, 135.40215964,
#        134.91598541, 133.42950566, 133.02794274, 132.88200684,
#        132.73542515, 132.61242185, 132.34803047, 134.02103634,
#        134.28333328, 133.6278321 , 133.51162338, 133.38924885,
#        132.900669  , 131.41178374, 131.00781539, 130.85947412,
#        130.71048711, 130.58507853, 130.31828187, 131.98888249,
#        132.24877419, 131.59086778, 131.47225383, 131.34747409,
#        130.85648901, 129.36519853, 128.95882497, 128.80807849,
#        128.65668627, 128.52887247, 128.2596706 , 129.92786601,
#        130.1853525 , 129.52504087, 129.40402172, 129.27683676,
#        128.78344647, 127.28975078, 126.88097201, 126.72782032,
