# %%
from pandas_datareader import data
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
import urllib.request, json
import os
import numpy as np
import tensorflow as tf # This code has been tested with TensorFlow 1.6
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
from matplotlib import pyplot

# %%
file = "../data/dexcomData.csv"

# %%
glucose = pd.read_csv(file)

# %%
glucose = glucose[['Timestamp', 'Blood Glucose (mg/dL)']]

# %%
glucose.sort_values('Timestamp')
# Out:
#                  Timestamp  Blood Glucose (mg/dL)
# 73525  2017-09-11 22:22:07                   72.0
# 73524  2017-09-11 22:26:59                   78.0
# 73523  2017-09-11 22:31:59                   69.0
# 73522  2017-09-11 22:36:58                   70.0
# 73521  2017-09-11 22:41:59                   61.0
# 73520  2017-09-11 22:46:59                   39.0
# 73519  2017-09-11 22:51:59                   39.0
# 73518  2017-09-11 22:56:58                   39.0
# 73517  2017-09-11 23:01:59                   39.0
# 73516  2017-09-11 23:06:59                   39.0
# 73515  2017-09-11 23:11:59                   39.0
# 73514  2017-09-11 23:16:58                   39.0
# 73513  2017-09-11 23:21:59                   39.0
# 73512  2017-09-11 23:26:59                   48.0
# 73511  2017-09-11 23:41:59                   77.0
# 73510  2017-09-11 23:46:58                   80.0
# 73509  2017-09-11 23:51:58                   74.0
# 73508  2017-09-11 23:56:59                   73.0
# ...

# %%
high_read = glucose.loc[:,'Blood Glucose (mg/dL)'].max()
low_read = glucose.loc[:,'Blood Glucose (mg/dL)'].min()
mid_read = (high_read+low_read)/2

# %%
print(high_read)
# Out:
# 401.0

# %%
print(low_read)
# Out:
# 39.0

# %%
print(mid_read)
# Out:
# 220.0

# %%
glucose.plot()

# %%
glucose['Timestamp'] = glucose['Timestamp'].dt.strftime('%Y%m%d').astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-f7b6ca745d2a> in <module>
# ----> 1 glucose['Timestamp'] = glucose['Timestamp'].dt.strftime('%Y%m%d').astype(float)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370         if (name in self._internal_names_set or name in self._metadata or
#    4371                 name in self._accessors):
# -> 4372             return object.__getattribute__(self, name)
#    4373         else:
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     131             # we're accessing the attribute of the class, i.e., Dataset.geo
#     132             return self._accessor
# ...

# %%
X = glucose.values
train, test = X[0:-35000], X[-35000:]

# %%
history = [x for x in train]
predictions = list()
for i in range(len(test)):
    
	predictions.append(history[-1])
    
	history.append(test[i])

rmse = sqrt(mean_squared_error(test, predictions))
print('RMSE: %.3f' % rmse)

pyplot.plot(test)
pyplot.plot(predictions)
pyplot.show()
