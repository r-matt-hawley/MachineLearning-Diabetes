# %%
import pandas as pd
import matplotlib
from matplotlib import pyplot

# %%
file = "../data/dexcomData.csv"

# %%
def parser(x):
    return pd.datetime.strptime('190'+x, '%Y-%m')

# %%
glucose = pd.read_csv(file, parse_dates=[0])

# %%
glucose['Blood Glucose (mg/dL)'] = glucose['Blood Glucose (mg/dL)'].astype('float')

# %%
glucose = glucose[['Timestamp', 'Blood Glucose (mg/dL)']]

# %%
glucose['Timestamp'] = pd.to_datetime(glucose['Timestamp'])

# %%
glucose.set_index('Timestamp')
# Out:
#                      Blood Glucose (mg/dL)
# Timestamp
# 2018-10-27 21:27:07                  206.0
# 2018-10-27 21:22:07                  205.0
# 2018-10-27 21:17:07                  203.0
# 2018-10-27 21:12:07                  202.0
# 2018-10-27 21:07:07                  202.0
# 2018-10-27 21:02:07                  202.0
# 2018-10-27 20:57:07                  201.0
# 2018-10-27 20:52:07                  200.0
# 2018-10-27 20:47:07                  199.0
# 2018-10-27 20:42:07                  196.0
# 2018-10-27 20:37:07                  194.0
# 2018-10-27 20:32:07                  190.0
# 2018-10-27 20:27:07                  188.0
# 2018-10-27 20:22:07                  189.0
# 2018-10-27 20:17:07                  180.0
# 2018-10-27 20:12:07                  186.0
# 2018-10-27 20:07:07                  179.0
# 2018-10-27 20:02:07                  176.0
# 2018-10-27 19:57:07                  169.0
# 2018-10-27 19:52:07                  167.0
# ...

# %%
gplot = glucose.plot(kind = 'line',
                     x = 'Timestamp',
                     y = 'Blood Glucose (mg/dL)',
                     figsize = (22, 12),
                     use_index = 1,
                     title = 'Glucose Readings')
gplot.set_xlabel('Month / Year')
gplot.set_ylabel('Blood Glucose (mg/dL)')
# Out:
# Text(0, 0.5, 'Blood Glucose (mg/dL)')

# %%
pyplot.show()

# %%
from pandas.plotting import autocorrelation_plot

# %%
def parser(x):
    return pd.datetime.strptime('190'+x, '%Y-%m')

# %%
autocorrelation_plot(glucose)
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-993521e3f516> in <module>
# ----> 1 autocorrelation_plot(glucose)
#       2 pyplot.show()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_misc.py in autocorrelation_plot(series, ax, **kwds)
#     617     if ax is None:
#     618         ax = plt.gca(xlim=(1, n), ylim=(-1.0, 1.0))
# --> 619     mean = np.mean(data)
#     620     c0 = np.sum((data - mean) ** 2) / float(n)
#     621
#
# ~\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    3116
#    3117     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 3118                           out=out, **kwargs)
#    3119
#    3120
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#      73             is_float16_result = True
#      74
# ...
